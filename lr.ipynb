# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("housing.csv")

# %%
print(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['total_bedrooms'].fillna(method='ffill', inplace = True)
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
plt.scatter(df['population'], df['median_house_value'])

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.642151   1425.476744    499.539680       3.870671
# std        420.876678   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.corr()
# Out:
# /var/folders/d5/0nkl4bqj2712httng60lv1cr0000gn/T/ipykernel_41977/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.070442 -0.067535           -0.319312     0.925347
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# ...

# %%
import seaborn as sns
plt.figure(figsize= (10,8))
sns.heatmap(df.corr(), annot=True, cmap= 'coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
# /var/folders/d5/0nkl4bqj2712httng60lv1cr0000gn/T/ipykernel_41977/2942390468.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap= 'coolwarm', fmt='.2f')

# %%
df = df.drop(['total_bedrooms', 'longitude', 'population'], axis = 1)

# %%
plt.figure(figsize= (10,8))
sns.heatmap(df.corr(), annot=True, cmap= 'coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
# Out:
# /var/folders/d5/0nkl4bqj2712httng60lv1cr0000gn/T/ipykernel_41977/2736068008.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap= 'coolwarm', fmt='.2f')

# %%
plt.boxplot(df['median_income'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16574f450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1657edf90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16575c290>],
#  'medians': [<matplotlib.lines.Line2D at 0x1657ef510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x164e99d50>],
#  'means': []}

# %%
sns.regplot(x='households',y='median_house_value', data=df)
# Out:
# <Axes: xlabel='households', ylabel='median_house_value'>

# %%
df.ocean_proximity.nunique()
# Out:
# 5

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['ocean_proximity_encoded'] = le.fit_transform(df['ocean_proximity'])
op = pd.DataFrame({'ocean_proximity_encoded': df['ocean_proximity_encoded']})
op.head()
# Out:
#    ocean_proximity_encoded
# 0                        3
# 1                        3
# 2                        3
# 3                        3
# 4                        3

# %%
df = df.drop('ocean_proximity', axis = 1)

# %%
pd.concat([df, op], axis = 1)
df.head()
# Out:
#    latitude  housing_median_age  total_rooms  households  median_income  \
# 0     37.88                41.0        880.0       126.0         8.3252
# 1     37.86                21.0       7099.0      1138.0         8.3014
# 2     37.85                52.0       1467.0       177.0         7.2574
# 3     37.85                52.0       1274.0       219.0         5.6431
# 4     37.85                52.0       1627.0       259.0         3.8462
#
#    median_house_value  ocean_proximity_encoded
# 0            452600.0                        3
# 1            358500.0                        3
# 2            352100.0                        3
# 3            341300.0                        3
# 4            342200.0                        3

# %%
x = df.drop('median_house_value', axis = 1)
y = df['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.5529645793116376

# %%
new_data = pd.DataFrame({
    'latitude': 39,
    'housing_median_age': 36,
    'total_rooms': 1274.0,
    'households': 200,
    'median_income': 8.3014,
    'ocean_proximity_encoded': 3
}, index=[0])

# Make predictions using the trained linear regression model
predicted_value = lr.predict(new_data)

print("Predicted Median House Value:", predicted_value)
# Out:
# Predicted Median House Value: [409315.85203004]

# %%
import pickle

# %%
with open('lr.pkl', 'wb') as file:
  pickle.dump(lr, file)
